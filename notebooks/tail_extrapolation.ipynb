# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 1
# %aimport joint_proba
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
font_size = 12
plt.rc('font', size=font_size)
plt.rc('axes', titlesize=font_size)
plt.rc('axes', labelsize=font_size)
plt.rc('xtick', labelsize=font_size)
plt.rc('ytick', labelsize=font_size)
plt.rc('legend', fontsize=font_size)
plt.rc('figure', titlesize=font_size)

# %%
import pickle
# df = pd.read_csv('../datasets/D.txt', sep=';', index_col=0, parse_dates=True)
with open('../datasets/D.pkl', 'rb') as f:
    df = pickle.load(f)

df.head(2)
# Out:
#                        wind speed (m/s)   significant wave height (m)
# time (YYYY-MM-DD-HH)
# 1965-01-01 00:00:00             15.3839                        3.9879
# 1965-01-01 01:00:00             15.4990                        4.0086

# %%
data = df.iloc[:, 0]
test = joint_proba.Univariate(data, sample_coor=np.linspace(0, 2*data.max(), 1000))
test.fit(outlier_detect=True)
test.plot_diagnosis()
# Out:
# Step 1/3: Fitting bulk of the data
# Step 2/3: Fitting right tail
# Step 3/3: Fitting left tail
